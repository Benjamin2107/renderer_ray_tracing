# %%
from camera import Vec3, Ray, ray_color, Camera

# %%
camera = Camera()

# %%
max_color = 255
image_width = 400
image_height = int(camera.get__height_from_width(image_width))

viewport_height = 2.0
viewport_width = camera.get_width_from_height(viewport_height)

# %%
horizontal = Vec3(viewport_width, 0, 0)
vertical = Vec3(0, viewport_height, 0)
lower_left_corner = camera.origin - horizontal / 2 - vertical / 2 - Vec3(0, 0, camera.focal_length)

# %%
"""
Rendering Loop, adapted to needs for this task
"""
with open("2_output_image/img_gradient_blue_white_gradient.ppm", "w") as img:
    img.write(f"P3\n{image_width} {image_height}\n{max_color}\n")

    for j in range(image_height - 1, -1, -1):
        print(f"Lines left:{j}")
        for i in range(image_width):
            u = float(i) / (image_width-1)
            v = float(j) / (image_height-1)
            ray = Ray(camera.origin, lower_left_corner + horizontal*u + vertical*v -camera.origin)
            pixel_color = ray_color(ray)
            img.write(f"{int(pixel_color.get_x())} ")
            img.write(f"{int(pixel_color.get_y())} ")
            img.write(f"{int(pixel_color.get_z())} \n")

    img.close()
# Out:
# Lines left:224
# Lines left:223
# Lines left:222
# Lines left:221
# Lines left:220
# Lines left:219
# Lines left:218
# Lines left:217
# Lines left:216
# Lines left:215
# Lines left:214
# Lines left:213
# Lines left:212
# Lines left:211
# Lines left:210
# Lines left:209
# Lines left:208
# Lines left:207
# Lines left:206
# Lines left:205
# Lines left:204
# Lines left:203
# Lines left:202
# Lines left:201
# Lines left:200
# Lines left:199
# Lines left:198
# Lines left:197
# Lines left:196
# Lines left:195
# Lines left:194
# Lines left:193
# Lines left:192
# Lines left:191
# Lines left:190
# Lines left:189
# Lines left:188
# Lines left:187
# Lines left:186
# Lines left:185
# Lines left:184
# Lines left:183
# Lines left:182
# Lines left:181
# Lines left:180
# Lines left:179
# Lines left:178
# Lines left:177
# Lines left:176
# Lines left:175
# Lines left:174
# Lines left:173
# Lines left:172
# Lines left:171
# Lines left:170
# Lines left:169
# Lines left:168
# Lines left:167
# Lines left:166
# Lines left:165
# Lines left:164
# Lines left:163
# Lines left:162
# Lines left:161
# Lines left:160
# Lines left:159
# Lines left:158
# Lines left:157
# Lines left:156
# Lines left:155
# Lines left:154
# Lines left:153
# Lines left:152
# Lines left:151
# Lines left:150
# Lines left:149
# Lines left:148
# Lines left:147
# Lines left:146
# Lines left:145
# Lines left:144
# Lines left:143
# Lines left:142
# Lines left:141
# Lines left:140
# Lines left:139
# Lines left:138
# Lines left:137
# Lines left:136
# Lines left:135
# Lines left:134
# Lines left:133
# Lines left:132
# Lines left:131
# Lines left:130
# Lines left:129
# Lines left:128
# Lines left:127
# Lines left:126
# Lines left:125
# Lines left:124
# Lines left:123
# Lines left:122
# Lines left:121
# Lines left:120
# Lines left:119
# Lines left:118
# Lines left:117
# Lines left:116
# Lines left:115
# Lines left:114
# Lines left:113
# Lines left:112
# Lines left:111
# Lines left:110
# Lines left:109
# Lines left:108
# Lines left:107
# Lines left:106
# Lines left:105
# Lines left:104
# Lines left:103
# Lines left:102
# Lines left:101
# Lines left:100
# Lines left:99
# Lines left:98
# Lines left:97
# Lines left:96
# Lines left:95
# Lines left:94
# Lines left:93
# Lines left:92
# Lines left:91
# Lines left:90
# Lines left:89
# Lines left:88
# Lines left:87
# Lines left:86
# Lines left:85
# Lines left:84
# Lines left:83
# Lines left:82
# Lines left:81
# Lines left:80
# Lines left:79
# Lines left:78
# Lines left:77
# Lines left:76
# Lines left:75
# Lines left:74
# Lines left:73
# Lines left:72
# Lines left:71
# Lines left:70
# Lines left:69
# Lines left:68
# Lines left:67
# Lines left:66
# Lines left:65
# Lines left:64
# Lines left:63
# Lines left:62
# Lines left:61
# Lines left:60
# Lines left:59
# Lines left:58
# Lines left:57
# Lines left:56
# Lines left:55
# Lines left:54
# Lines left:53
# Lines left:52
# Lines left:51
# Lines left:50
# Lines left:49
# Lines left:48
# Lines left:47
# Lines left:46
# Lines left:45
# Lines left:44
# Lines left:43
# Lines left:42
# Lines left:41
# Lines left:40
# Lines left:39
# Lines left:38
# Lines left:37
# Lines left:36
# Lines left:35
# Lines left:34
# Lines left:33
# Lines left:32
# Lines left:31
# Lines left:30
# Lines left:29
# Lines left:28
# Lines left:27
# Lines left:26
# Lines left:25
# Lines left:24
# Lines left:23
# Lines left:22
# Lines left:21
# Lines left:20
# Lines left:19
# Lines left:18
# Lines left:17
# Lines left:16
# Lines left:15
# Lines left:14
# Lines left:13
# Lines left:12
# Lines left:11
# Lines left:10
# Lines left:9
# Lines left:8
# Lines left:7
# Lines left:6
# Lines left:5
# Lines left:4
# Lines left:3
# Lines left:2
# Lines left:1
# Lines left:0
